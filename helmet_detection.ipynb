# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
import zipfile

# %%
zipfile = zipfile.ZipFile('/content/helmet.yolov11.zip')

# %%
zipfile.extractall()

# %%
model.train(data="/content/data.yaml",epochs=10)
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.save("helmet.pt")

# %%
new_model = YOLO("helmet.pt")

# %%
pred = new_model.predict("/content/test/images/179_dddd00f8_66ce_4f79_a483_3c1197fd5f66_jpeg_jpg.rf.1cz2MP8fNmBZ4c1PK5Cu.jpg")
# Out:
# image 1/1 /content/test/images/179_dddd00f8_66ce_4f79_a483_3c1197fd5f66_jpeg_jpg.rf.1cz2MP8fNmBZ4c1PK5Cu.jpg: 640x480 1 helmet, 51.0ms
# Speed: 2.3ms preprocess, 51.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024>

# %%
model.predict('/content/videee.mp4', save=True, show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/524) /content/videee.mp4: 384x640 (no detections), 50.5ms
# video 1/1 (frame 2/524) /content/videee.mp4: 384x640 (no detections), 7.6ms
# video 1/1 (frame 3/524) /content/videee.mp4: 384x640 (no detections), 8.0ms
# video 1/1 (frame 4/524) /content/videee.mp4: 384x640 (no detections), 7.4ms
# ...
